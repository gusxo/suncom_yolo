# %%
import cv2
import matplotlib.pyplot as plt

# %%
# file = "/home/user/mount1/620동원/drive 1/SCMedia/VIDEO/2022/11/16/CAM4/CAM4_20221116182159.mp4"
# x1 = 1250 ; y1 = 800 ; x2 = 1750 ; y2 = -1 ;

# file = "/home/user/mount1/722오룡/drive 2/SCMedia/VIDEO/2022/09/04/CAM4/CAM4_20220904001508.mp4"
# x1 = 500 ; y1 = 850 ; x2 = 1100 ; y2 = -1 ;

# file = "/home/user/mount1/723오룡/drive/SCMedia/VIDEO/2021/12/07/CAM3/ch3_20211207182235.mp4"
# x1 = 400 ; y1 = 800 ; x2 = 1000 ; y2 = -1 ;

# file = "/home/user/mount1/토니나3/drive 2/VIDEO/2022/10/09/CAM3/CAM3_20221009171453.mp4"
# x1 = 400 ; y1 = 600 ; x2 = 1400 ; y2 = -1 ;

v = cv2.VideoCapture(file)
if not v.isOpened():
    raise Exception()
ret, img = v.read()
if not ret:
    raise Exception()
print(img.shape)
if x2 == -1:
    x2 = img.shape[1]
if y2 == -1:
    y2 = img.shape[0]
img = cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 0), 3)
plt.imshow(img)
v.release()
# Out:
# (1080, 1920, 3)
