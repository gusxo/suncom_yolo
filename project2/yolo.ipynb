# %%
from IPython import display
display.clear_output()
 
import ultralytics
ultralytics.checks()

import torch
torch.cuda.is_available()
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
# Setup complete ✅ (32 CPUs, 94.1 GB RAM, 881.4/1832.2 GB disk)
# True

# %%
from ultralytics import YOLO
 
# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
 
# Train the model
model.train(data='data.yaml', epochs=300, device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.0.164 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.158 🚀 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
# ...

# %%
model.val()
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
# val: Scanning /home/user/pro2/valid/labels.cache... 20 images, 1 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  7.94it/s]
#                    all         20         19       0.49      0.798      0.899       0.68
#             BigeyeTuna         20         18      0.915      0.596      0.802      0.465
#          YellowfinTuna         20          1     0.0654          1      0.995      0.895
# Speed: 0.8ms preprocess, 7.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
results = model.predict(source="/home/user/share/project2/ship1/2022_11_11", save=True)
# Out:
# image 1/636 /home/user/share/project2/ship1/2022_11_11/0.png: 384x640 1 BigeyeTuna, 49.2ms
# image 2/636 /home/user/share/project2/ship1/2022_11_11/1.png: 384x640 (no detections), 1.6ms
# image 3/636 /home/user/share/project2/ship1/2022_11_11/10.png: 384x640 (no detections), 1.5ms
# image 4/636 /home/user/share/project2/ship1/2022_11_11/100.png: 384x640 1 BigeyeTuna, 1 YellowfinTuna, 1.4ms
# image 5/636 /home/user/share/project2/ship1/2022_11_11/101.png: 384x640 1 BigeyeTuna, 1.4ms
# image 6/636 /home/user/share/project2/ship1/2022_11_11/102.png: 384x640 1 YellowfinTuna, 1.4ms
# image 7/636 /home/user/share/project2/ship1/2022_11_11/103.png: 384x640 (no detections), 1.4ms
# image 8/636 /home/user/share/project2/ship1/2022_11_11/104.png: 384x640 (no detections), 1.4ms
# image 9/636 /home/user/share/project2/ship1/2022_11_11/105.png: 384x640 (no detections), 1.4ms
# image 10/636 /home/user/share/project2/ship1/2022_11_11/106.png: 384x640 (no detections), 1.4ms
# ...

# %%
results = model.predict(source="/home/user/share/project2/ship1/2022_11_15", save=True)
# Out:
# image 1/558 /home/user/share/project2/ship1/2022_11_15/0.png: 384x640 (no detections), 1.7ms
# image 2/558 /home/user/share/project2/ship1/2022_11_15/1.png: 384x640 (no detections), 1.6ms
# image 3/558 /home/user/share/project2/ship1/2022_11_15/10.png: 384x640 (no detections), 1.7ms
# image 4/558 /home/user/share/project2/ship1/2022_11_15/100.png: 384x640 (no detections), 1.7ms
# image 5/558 /home/user/share/project2/ship1/2022_11_15/101.png: 384x640 (no detections), 1.5ms
# image 6/558 /home/user/share/project2/ship1/2022_11_15/102.png: 384x640 (no detections), 1.4ms
# image 7/558 /home/user/share/project2/ship1/2022_11_15/103.png: 384x640 (no detections), 1.4ms
# image 8/558 /home/user/share/project2/ship1/2022_11_15/104.png: 384x640 (no detections), 1.4ms
# image 9/558 /home/user/share/project2/ship1/2022_11_15/105.png: 384x640 (no detections), 1.4ms
# image 10/558 /home/user/share/project2/ship1/2022_11_15/106.png: 384x640 (no detections), 1.4ms
# ...

# %%
results = model.predict(source="/home/user/share/project2/ship2/2022_08_27", save=True)
# Out:
# image 1/503 /home/user/share/project2/ship2/2022_08_27/0.png: 384x640 1 BigeyeTuna, 1.7ms
# image 2/503 /home/user/share/project2/ship2/2022_08_27/1.png: 384x640 (no detections), 1.6ms
# image 3/503 /home/user/share/project2/ship2/2022_08_27/10.png: 384x640 (no detections), 1.7ms
# image 4/503 /home/user/share/project2/ship2/2022_08_27/100.png: 384x640 (no detections), 1.5ms
# image 5/503 /home/user/share/project2/ship2/2022_08_27/101.png: 384x640 (no detections), 1.4ms
# image 6/503 /home/user/share/project2/ship2/2022_08_27/102.png: 384x640 (no detections), 1.4ms
# image 7/503 /home/user/share/project2/ship2/2022_08_27/103.png: 384x640 (no detections), 1.3ms
# image 8/503 /home/user/share/project2/ship2/2022_08_27/104.png: 384x640 (no detections), 1.4ms
# image 9/503 /home/user/share/project2/ship2/2022_08_27/105.png: 384x640 (no detections), 1.4ms
# image 10/503 /home/user/share/project2/ship2/2022_08_27/106.png: 384x640 (no detections), 1.3ms
# ...

# %%
results = model.predict(source="/home/user/share/project2/ship3/2021_11_28", save=True)
# Out:
# image 1/196 /home/user/share/project2/ship3/2021_11_28/0.png: 384x640 1 BigeyeTuna, 1.5ms
# image 2/196 /home/user/share/project2/ship3/2021_11_28/1.png: 384x640 1 BigeyeTuna, 1.4ms
# image 3/196 /home/user/share/project2/ship3/2021_11_28/10.png: 384x640 (no detections), 1.4ms
# image 4/196 /home/user/share/project2/ship3/2021_11_28/100.png: 384x640 1 YellowfinTuna, 1.4ms
# image 5/196 /home/user/share/project2/ship3/2021_11_28/101.png: 384x640 (no detections), 1.4ms
# image 6/196 /home/user/share/project2/ship3/2021_11_28/102.png: 384x640 1 BigeyeTuna, 1.4ms
# image 7/196 /home/user/share/project2/ship3/2021_11_28/103.png: 384x640 1 BigeyeTuna, 1.4ms
# image 8/196 /home/user/share/project2/ship3/2021_11_28/104.png: 384x640 (no detections), 1.4ms
# image 9/196 /home/user/share/project2/ship3/2021_11_28/105.png: 384x640 1 BigeyeTuna, 1.4ms
# image 10/196 /home/user/share/project2/ship3/2021_11_28/106.png: 384x640 (no detections), 1.4ms
# ...

# %%
results = model.predict(source="/home/user/share/project2/ship3/2021_11_29", save=True)
# Out:
# image 1/747 /home/user/share/project2/ship3/2021_11_29/0.png: 384x640 (no detections), 1.5ms
# image 2/747 /home/user/share/project2/ship3/2021_11_29/1.png: 384x640 (no detections), 1.5ms
# image 3/747 /home/user/share/project2/ship3/2021_11_29/10.png: 384x640 (no detections), 1.4ms
# image 4/747 /home/user/share/project2/ship3/2021_11_29/100.png: 384x640 (no detections), 1.4ms
# image 5/747 /home/user/share/project2/ship3/2021_11_29/101.png: 384x640 (no detections), 1.4ms
# image 6/747 /home/user/share/project2/ship3/2021_11_29/102.png: 384x640 (no detections), 1.4ms
# image 7/747 /home/user/share/project2/ship3/2021_11_29/103.png: 384x640 (no detections), 1.4ms
# image 8/747 /home/user/share/project2/ship3/2021_11_29/104.png: 384x640 (no detections), 1.4ms
# image 9/747 /home/user/share/project2/ship3/2021_11_29/105.png: 384x640 (no detections), 1.4ms
# image 10/747 /home/user/share/project2/ship3/2021_11_29/106.png: 384x640 (no detections), 1.4ms
# ...

# %%
results = model.predict(source="/home/user/share/project2/ship4/2022_07_11", save=True)
# Out:
# image 1/463 /home/user/share/project2/ship4/2022_07_11/0.png: 384x640 (no detections), 1.5ms
# image 2/463 /home/user/share/project2/ship4/2022_07_11/1.png: 384x640 (no detections), 1.4ms
# image 3/463 /home/user/share/project2/ship4/2022_07_11/10.png: 384x640 (no detections), 1.5ms
# image 4/463 /home/user/share/project2/ship4/2022_07_11/100.png: 384x640 1 YellowfinTuna, 1.4ms
# image 5/463 /home/user/share/project2/ship4/2022_07_11/101.png: 384x640 (no detections), 1.4ms
# image 6/463 /home/user/share/project2/ship4/2022_07_11/102.png: 384x640 1 BigeyeTuna, 1 YellowfinTuna, 1.4ms
# image 7/463 /home/user/share/project2/ship4/2022_07_11/103.png: 384x640 (no detections), 1.4ms
# image 8/463 /home/user/share/project2/ship4/2022_07_11/104.png: 384x640 (no detections), 1.4ms
# image 9/463 /home/user/share/project2/ship4/2022_07_11/105.png: 384x640 (no detections), 1.4ms
# image 10/463 /home/user/share/project2/ship4/2022_07_11/106.png: 384x640 (no detections), 1.4ms
# ...

# %%
model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# PyTorch: starting from 'runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.9 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ONNX: export success ✅ 0.2s, saved as 'runs/detect/train2/weights/best.onnx' (11.7 MB)
#
# Export complete (0.2s)
# Results saved to /home/user/pro2/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=runs/detect/train2/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train2/weights/best.onnx imgsz=640 data=data.yaml
# Visualize:       https://netron.app
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# 'runs/detect/train2/weights/best.onnx'

# %%
results[2].boxes.conf
# Out:
# tensor([], device='cuda:0')
