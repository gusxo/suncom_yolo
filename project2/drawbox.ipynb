# %%
import cv2
import matplotlib.pyplot as plt

# %%
file = "/home/user/share/project2/ship2/2022_09_06/95.png"
t = 150
l = 300
b = 500
r = 650

img = cv2.imread(file)
print(img.shape)
if b == -1:
    b = img.shape[0]
if r == -1:
    r = img.shape[1]
img = cv2.rectangle(img, (l, t), (r, b), (255, 0, 0), 3)
plt.imshow(img)
# Out:
# (540, 960, 3)
